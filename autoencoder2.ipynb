# %%
# Imports
import os
from tqdm import tqdm
import cv2
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
from datetime import datetime

from sklearn.model_selection import train_test_split
import tensorflow as tf
from keras import layers
from keras.models import Model
from tensorflow.keras.utils import Sequence
from keras.optimizers import Adam
from keras import backend as K
from keras.models import load_model

from helper_functions import get_picture_filenames_from_folder, load_and_transform_pictures, display_blur_sharp_and_pred_images
# Out:
# 2023-12-21 22:05:45.407745: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-12-21 22:05:47.008229: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-21 22:05:47.008309: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-21 22:05:47.150139: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-21 22:05:47.200864: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-21 22:05:55.680561: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
# Setup
plt.rcParams["figure.figsize"] = [9, 16]

# %%
# Check if GPU is available
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# Path helpers
blurred_train_path = os.path.join('clean_data', 'train', 'blur')
sharp_train_path = os.path.join('clean_data', 'train', 'sharp')
blurred_test_path = os.path.join('clean_data', 'test', 'blur')
sharp_test_path = os.path.join('clean_data', 'test', 'sharp')

# %%
# Data generator class
class DataGenerator(Sequence):
    # Based on https://github.com/AryanSethi/No-Blur/blob/master/model_exps/try4.ipynb
    
    def __init__(self, base_dir,base_dir2, output_size, shuffle=False, batch_size=10):
        self.base_dir = base_dir
        self.base_dir2 = base_dir2
        self.output_size = output_size
        self.shuffle = shuffle
        self.batch_size = batch_size
        self.all_x = [f for f in os.listdir(base_dir) if f.endswith(".png")]
        self.all_y = [f for f in os.listdir(base_dir2) if f.endswith(".png")]
        self.on_epoch_end()

    def on_epoch_end(self):
        self.indices = np.arange(len(self.all_x))
        if self.shuffle:
            np.random.shuffle(self.indices)

    def __len__(self):
        return int(len(self.all_x) / self.batch_size)

    def __getitem__(self, idx):
        X = np.empty((self.batch_size, *self.output_size, 3))
        Y = np.empty((self.batch_size, *self.output_size, 3))

        indices = self.indices[idx*(self.batch_size): (idx+1)*(self.batch_size)]

        for i,j in enumerate(indices):
            img_path = os.path.join(self.base_dir,self.all_x[j])
            img_path2 = os.path.join(self.base_dir2,self.all_y[j])

            img  = cv2.imread(img_path)
            img2 = cv2.imread(img_path2)
            X[i,] = img
            Y[i,] = img2
        X= X.astype('float32')/255
        Y= Y.astype('float32')/255
        return X, Y

# %%
# Easy autoencoder
def deblurring_autoencoder():
    input = layers.Input(shape=(720, 1280, 3), name='autoencoder2')
    
    # Encoder
    x = layers.Conv2D(32, (3, 3), activation="relu", padding="same")(input)
    x = layers.MaxPooling2D((2, 2), padding="same")(x)

    # Decoder
    x = layers.Conv2DTranspose(32, (3, 3), strides=2, activation="relu", padding="same")(x)
    final_deconv = layers.Conv2D(3, (3, 3), activation="sigmoid", padding="same")(x)
    return Model(input, final_deconv, name='autoencoder2')

# %%
model = deblurring_autoencoder()
model.summary()
# Out:
# Model: "autoencoder2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  autoencoder2 (InputLayer)   [(None, 720, 1280, 3)]    0
#
#  conv2d (Conv2D)             (None, 720, 1280, 32)     896
#
#  max_pooling2d (MaxPooling2  (None, 360, 640, 32)      0
#  D)
#
#  conv2d_transpose (Conv2DTr  (None, 720, 1280, 32)     9248
#  anspose)
#
#  conv2d_1 (Conv2D)           (None, 720, 1280, 3)      867
#
# =================================================================
# Total params: 11011 (43.01 KB)
# Trainable params: 11011 (43.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# 2023-12-21 22:06:09.220410: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 30953 MB memory:  -> device: 0, name: Tesla V100-SXM2-32GB, pci bus id: 0000:1b:00.0, compute capability: 7.0

# %%
# Define model inputs, compile model

train = DataGenerator(blurred_train_path, sharp_train_path, (720,1280), batch_size=8, shuffle=False)
test  = DataGenerator(blurred_test_path, sharp_test_path, (720,1280), batch_size=8, shuffle=False)
opt=Adam(learning_rate=0.001)

now = datetime.now()
checkpoint_filepath = f"models/autoencoder2_{now.year}_{now.month}_{now.day}T{now.hour}_{now.minute}_epoch"+"{epoch:02d}_mae_{loss:.4f}_val_mae_{val_loss:.4f}.keras"
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    verbose = 1,
    save_best_only=False)

model.compile(optimizer=opt, loss='mae')

# %%
# Model training

history = model.fit(
    train,
    epochs=30,
    callbacks = [model_checkpoint_callback],
    validation_data = test
)
# Out:
# Epoch 1/30
# 2023-12-21 22:06:16.354268: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8904
# 2023-12-21 22:06:26.715915: I external/local_xla/xla/service/service.cc:168] XLA service 0x2b97a7d1fbd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-21 22:06:26.715964: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Tesla V100-SXM2-32GB, Compute Capability 7.0
# 2023-12-21 22:06:26.728662: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1703189187.002759  107907 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 262/262 [==============================] - ETA: 0s - loss: 0.0747
# Epoch 1: saving model to models/autoencoder2_2023_12_21T22_6_epoch01_mae_0.0747_val_mae_0.0465.keras
# 262/262 [==============================] - 580s 2s/step - loss: 0.0747 - val_loss: 0.0465
# Epoch 2/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0414
# Epoch 2: saving model to models/autoencoder2_2023_12_21T22_6_epoch02_mae_0.0414_val_mae_0.0421.keras
# 262/262 [==============================] - 412s 2s/step - loss: 0.0414 - val_loss: 0.0421
# Epoch 3/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0394
# Epoch 3: saving model to models/autoencoder2_2023_12_21T22_6_epoch03_mae_0.0394_val_mae_0.0412.keras
# 262/262 [==============================] - 421s 2s/step - loss: 0.0394 - val_loss: 0.0412
# Epoch 4/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0382
# Epoch 4: saving model to models/autoencoder2_2023_12_21T22_6_epoch04_mae_0.0382_val_mae_0.0403.keras
# 262/262 [==============================] - 395s 2s/step - loss: 0.0382 - val_loss: 0.0403
# Epoch 5/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0381
# Epoch 5: saving model to models/autoencoder2_2023_12_21T22_6_epoch05_mae_0.0381_val_mae_0.0419.keras
# 262/262 [==============================] - 396s 2s/step - loss: 0.0381 - val_loss: 0.0419
# Epoch 6/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0378
# Epoch 6: saving model to models/autoencoder2_2023_12_21T22_6_epoch06_mae_0.0378_val_mae_0.0396.keras
# 262/262 [==============================] - 363s 1s/step - loss: 0.0378 - val_loss: 0.0396
# Epoch 7/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0375
# Epoch 7: saving model to models/autoencoder2_2023_12_21T22_6_epoch07_mae_0.0375_val_mae_0.0392.keras
# 262/262 [==============================] - 406s 2s/step - loss: 0.0375 - val_loss: 0.0392
# Epoch 8/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0375
# Epoch 8: saving model to models/autoencoder2_2023_12_21T22_6_epoch08_mae_0.0375_val_mae_0.0408.keras
# 262/262 [==============================] - 539s 2s/step - loss: 0.0375 - val_loss: 0.0408
# Epoch 9/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0378
# Epoch 9: saving model to models/autoencoder2_2023_12_21T22_6_epoch09_mae_0.0378_val_mae_0.0388.keras
# 262/262 [==============================] - 365s 1s/step - loss: 0.0378 - val_loss: 0.0388
# Epoch 10/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0374
# Epoch 10: saving model to models/autoencoder2_2023_12_21T22_6_epoch10_mae_0.0374_val_mae_0.0386.keras
# 262/262 [==============================] - 337s 1s/step - loss: 0.0374 - val_loss: 0.0386
# Epoch 11/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0370
# Epoch 11: saving model to models/autoencoder2_2023_12_21T22_6_epoch11_mae_0.0370_val_mae_0.0391.keras
# 262/262 [==============================] - 470s 2s/step - loss: 0.0370 - val_loss: 0.0391
# Epoch 12/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0373
# Epoch 12: saving model to models/autoencoder2_2023_12_21T22_6_epoch12_mae_0.0373_val_mae_0.0384.keras
# 262/262 [==============================] - 345s 1s/step - loss: 0.0373 - val_loss: 0.0384
# Epoch 13/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0369
# Epoch 13: saving model to models/autoencoder2_2023_12_21T22_6_epoch13_mae_0.0369_val_mae_0.0384.keras
# 262/262 [==============================] - 340s 1s/step - loss: 0.0369 - val_loss: 0.0384
# Epoch 14/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0366
# Epoch 14: saving model to models/autoencoder2_2023_12_21T22_6_epoch14_mae_0.0366_val_mae_0.0383.keras
# 262/262 [==============================] - 352s 1s/step - loss: 0.0366 - val_loss: 0.0383
# Epoch 15/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0369
# Epoch 15: saving model to models/autoencoder2_2023_12_21T22_6_epoch15_mae_0.0369_val_mae_0.0400.keras
# 262/262 [==============================] - 378s 1s/step - loss: 0.0369 - val_loss: 0.0400
# Epoch 16/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0366
# Epoch 16: saving model to models/autoencoder2_2023_12_21T22_6_epoch16_mae_0.0366_val_mae_0.0384.keras
# 262/262 [==============================] - 440s 2s/step - loss: 0.0366 - val_loss: 0.0384
# Epoch 17/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0363
# Epoch 17: saving model to models/autoencoder2_2023_12_21T22_6_epoch17_mae_0.0363_val_mae_0.0382.keras
# 262/262 [==============================] - 485s 2s/step - loss: 0.0363 - val_loss: 0.0382
# Epoch 18/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0361
# Epoch 18: saving model to models/autoencoder2_2023_12_21T22_6_epoch18_mae_0.0361_val_mae_0.0375.keras
# 262/262 [==============================] - 490s 2s/step - loss: 0.0361 - val_loss: 0.0375
# Epoch 19/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0361
# Epoch 19: saving model to models/autoencoder2_2023_12_21T22_6_epoch19_mae_0.0361_val_mae_0.0374.keras
# 262/262 [==============================] - 523s 2s/step - loss: 0.0361 - val_loss: 0.0374
# Epoch 20/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0362
# Epoch 20: saving model to models/autoencoder2_2023_12_21T22_6_epoch20_mae_0.0362_val_mae_0.0383.keras
# 262/262 [==============================] - 516s 2s/step - loss: 0.0362 - val_loss: 0.0383
# Epoch 21/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0359
# Epoch 21: saving model to models/autoencoder2_2023_12_21T22_6_epoch21_mae_0.0359_val_mae_0.0370.keras
# 262/262 [==============================] - 490s 2s/step - loss: 0.0359 - val_loss: 0.0370
# Epoch 22/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0354
# Epoch 22: saving model to models/autoencoder2_2023_12_21T22_6_epoch22_mae_0.0354_val_mae_0.0368.keras
# 262/262 [==============================] - 445s 2s/step - loss: 0.0354 - val_loss: 0.0368
# Epoch 23/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0354
# Epoch 23: saving model to models/autoencoder2_2023_12_21T22_6_epoch23_mae_0.0354_val_mae_0.0365.keras
# 262/262 [==============================] - 439s 2s/step - loss: 0.0354 - val_loss: 0.0365
# Epoch 24/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0348
# Epoch 24: saving model to models/autoencoder2_2023_12_21T22_6_epoch24_mae_0.0348_val_mae_0.0363.keras
# 262/262 [==============================] - 489s 2s/step - loss: 0.0348 - val_loss: 0.0363
# Epoch 25/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0349
# Epoch 25: saving model to models/autoencoder2_2023_12_21T22_6_epoch25_mae_0.0349_val_mae_0.0357.keras
# 262/262 [==============================] - 492s 2s/step - loss: 0.0349 - val_loss: 0.0357
# Epoch 26/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0346
# Epoch 26: saving model to models/autoencoder2_2023_12_21T22_6_epoch26_mae_0.0346_val_mae_0.0355.keras
# 262/262 [==============================] - 394s 2s/step - loss: 0.0346 - val_loss: 0.0355
# Epoch 27/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0346
# Epoch 27: saving model to models/autoencoder2_2023_12_21T22_6_epoch27_mae_0.0346_val_mae_0.0355.keras
# 262/262 [==============================] - 362s 1s/step - loss: 0.0346 - val_loss: 0.0355
# Epoch 28/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0345
# Epoch 28: saving model to models/autoencoder2_2023_12_21T22_6_epoch28_mae_0.0345_val_mae_0.0358.keras
# 262/262 [==============================] - 378s 1s/step - loss: 0.0345 - val_loss: 0.0358
# Epoch 29/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0343
# Epoch 29: saving model to models/autoencoder2_2023_12_21T22_6_epoch29_mae_0.0343_val_mae_0.0354.keras
# 262/262 [==============================] - 366s 1s/step - loss: 0.0343 - val_loss: 0.0354
# Epoch 30/30
# 262/262 [==============================] - ETA: 0s - loss: 0.0345
# Epoch 30: saving model to models/autoencoder2_2023_12_21T22_6_epoch30_mae_0.0345_val_mae_0.0364.keras
# 262/262 [==============================] - 347s 1s/step - loss: 0.0345 - val_loss: 0.0364

# %%
# Load best model
model_name = 'autoencoder2_2023_12_21T22_6_epoch29_mae_0.0343_val_mae_0.0354.keras'
model_path = 'models'
best_model = load_model(os.path.join(model_path, model_name))

# %%
# Load in data splits for testing
num_of_test_files = 10
test_batch_filenames = get_picture_filenames_from_folder(blurred_test_path)[:num_of_test_files]
blurred_test_batch = load_and_transform_pictures(test_batch_filenames, blurred_test_path)
sharp_test_batch = load_and_transform_pictures(test_batch_filenames, sharp_test_path)

# %%
# Predicting with best model
predictions = np.clip(best_model.predict(blurred_test_batch), 0, 1).astype('float64')
# Out:
# 1/1 [==============================] - 4s 4s/step

# %%
# Display blurred, predicted and sharp images
img_id = 0
display_blur_sharp_and_pred_images(img_id, blurred_test_batch, sharp_test_batch, predictions)
